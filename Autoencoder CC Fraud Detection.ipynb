# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, decomposition
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
def show_pca_df(df):
	x = df[df.columns[1:30]].to_numpy()
	y = df[df.columns[30]].to_numpy()

	x = preprocessing.MinMaxScaler().fit_transform(x)
	pca = decomposition.PCA(n_components=3)
	pca_result = pca.fit_transform(x)
	print(pca.explained_variance_ratio_)

	pca_df = pd.DataFrame(data=pca_result, columns=['pc_1', 'pc_2', 'pc_3'])
	pca_df = pd.concat([pca_df, pd.DataFrame({'label': y})], axis=1)

	ax = Axes3D(plt.figure(figsize=(8, 8)))
	ax.scatter(xs=pca_df['pc_1'], ys=pca_df['pc_2'], zs=pca_df['pc_3'], c=pca_df['label'], s=25)
	ax.set_xlabel("pc_1")
	ax.set_ylabel("pc_2")
	ax.set_zlabel("pc_3")
	plt.show()

df = pd.read_csv('Desktop/ML Python files/CreditCardFraud-Autoencoder/creditcard.csv')

show_pca_df(df)
# Out:
# [0.13501016 0.12577773 0.12031404]

# %%
df_anomaly = df[df[df.columns[30]] > 0]
df_normal = df[df[df.columns[30]] == 0].sample(n=df_anomaly.size, random_state=1, axis='index')
df = pd.concat([ df_anomaly, df_normal])

show_pca_df(df)
# Out:
# [0.20577961 0.14728955 0.09800454]

# %%
df = pd.read_csv('Desktop/ML Python files/CreditCardFraud-Autoencoder/creditcard.csv')

x = df[df.columns[1:30]].to_numpy()
y = df[df.columns[30]].to_numpy()

# prepare data
df = pd.concat([pd.DataFrame(x), pd.DataFrame({'anomaly': y})], axis=1)
normal_events = df[df['anomaly'] == 0]
abnormal_events = df[df['anomaly'] == 1]

normal_events = normal_events.loc[:, normal_events.columns != 'anomaly']
abnormal_events = abnormal_events.loc[:, abnormal_events.columns != 'anomaly']

# scaling
scaler = preprocessing.MinMaxScaler()
scaler.fit(df.drop('anomaly', 1))

scaled_data = scaler.transform(normal_events)

# 80% percent of dataset is designated to training
from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(scaled_data, test_size=0.2)

n_features = x.shape[1]

# model
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations
encoder = keras.Sequential(name='encoder')
encoder.add(layer=layers.Dense(units=20, activation=activations.relu, input_shape=[n_features]))
encoder.add(layers.Dropout(0.1))
encoder.add(layer=layers.Dense(units=10, activation=activations.relu))
encoder.add(layer=layers.Dense(units=5, activation=activations.relu))

decoder = keras.Sequential(name='decoder')
decoder.add(layer=layers.Dense(units=10, activation=activations.relu, input_shape=[5]))
decoder.add(layer=layers.Dense(units=20, activation=activations.relu))
decoder.add(layers.Dropout(0.1))
decoder.add(layer=layers.Dense(units=n_features, activation=activations.sigmoid))

autoencoder = keras.Sequential([encoder, decoder])

from tensorflow.keras import losses, optimizers, metrics, callbacks

autoencoder.compile(
	loss=losses.MSE,
	optimizer=optimizers.Adam(),
	metrics=[metrics.mean_squared_error])

# train model
es = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, patience=20, restore_best_weights=True)
history = autoencoder.fit(x=train_data, y=train_data, epochs=100, verbose=1, validation_data=[test_data, test_data], callbacks=[es])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Train on 227452 samples, validate on 56863 samples
# Epoch 1/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 2/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 3/100
# 227452/227452 [==============================] - 9s 39us/sample - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.9540e-04 - val_mean_squared_error: 9.9540e-04
# Epoch 4/100
# 227452/227452 [==============================] - 9s 39us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.7258e-04 - val_mean_squared_error: 9.7258e-04
# Epoch 5/100
# 227452/227452 [==============================] - 9s 39us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.5572e-04 - val_mean_squared_error: 9.5572e-04
# Epoch 6/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.3557e-04 - val_mean_squared_error: 9.3557e-04
# Epoch 7/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.3059e-04 - val_mean_squared_error: 9.3059e-04
# Epoch 8/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.5348e-04 - val_mean_squared_error: 9.5348e-04
# Epoch 9/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.9578e-04 - mean_squared_error: 9.9578e-04 - val_loss: 9.1603e-04 - val_mean_squared_error: 9.1603e-04
# Epoch 10/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.9055e-04 - mean_squared_error: 9.9056e-04 - val_loss: 9.4481e-04 - val_mean_squared_error: 9.4481e-04
# Epoch 11/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.8398e-04 - mean_squared_error: 9.8397e-04 - val_loss: 9.4303e-04 - val_mean_squared_error: 9.4303e-04
# Epoch 12/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.7784e-04 - mean_squared_error: 9.7784e-04 - val_loss: 9.1262e-04 - val_mean_squared_error: 9.1262e-04
# Epoch 13/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.7543e-04 - mean_squared_error: 9.7543e-04 - val_loss: 9.2998e-04 - val_mean_squared_error: 9.2999e-04
# Epoch 14/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.7194e-04 - mean_squared_error: 9.7193e-04 - val_loss: 9.4839e-04 - val_mean_squared_error: 9.4839e-04
# Epoch 15/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.7080e-04 - mean_squared_error: 9.7080e-04 - val_loss: 9.1356e-04 - val_mean_squared_error: 9.1356e-04
# Epoch 16/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.6855e-04 - mean_squared_error: 9.6855e-04 - val_loss: 9.0715e-04 - val_mean_squared_error: 9.0715e-04
# Epoch 17/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.6680e-04 - mean_squared_error: 9.6680e-04 - val_loss: 8.9920e-04 - val_mean_squared_error: 8.9920e-04
# Epoch 18/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.6667e-04 - val_mean_squared_error: 9.6667e-04
# Epoch 19/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.8393e-04 - val_mean_squared_error: 9.8393e-04
# Epoch 20/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.6113e-04 - val_mean_squared_error: 9.6114e-04
# Epoch 21/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.9764e-04 - val_mean_squared_error: 9.9764e-04
# Epoch 22/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.2171e-04 - val_mean_squared_error: 9.2171e-04
# Epoch 23/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.4790e-04 - val_mean_squared_error: 9.4790e-04
# Epoch 24/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.3958e-04 - val_mean_squared_error: 9.3958e-04
# Epoch 25/100
# 227452/227452 [==============================] - 10s 43us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.1798e-04 - val_mean_squared_error: 9.1798e-04
# Epoch 26/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 9.1238e-04 - val_mean_squared_error: 9.1238e-04
# Epoch 27/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.9963e-04 - mean_squared_error: 9.9963e-04 - val_loss: 9.0678e-04 - val_mean_squared_error: 9.0678e-04
# Epoch 28/100
# 227452/227452 [==============================] - 10s 45us/sample - loss: 9.9855e-04 - mean_squared_error: 9.9855e-04 - val_loss: 8.9280e-04 - val_mean_squared_error: 8.9280e-04
# Epoch 29/100
# 227452/227452 [==============================] - 12s 53us/sample - loss: 9.9773e-04 - mean_squared_error: 9.9773e-04 - val_loss: 9.1780e-04 - val_mean_squared_error: 9.1780e-04
# Epoch 30/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.9612e-04 - mean_squared_error: 9.9612e-04 - val_loss: 8.9216e-04 - val_mean_squared_error: 8.9216e-04
# Epoch 31/100
# 227452/227452 [==============================] - 10s 43us/sample - loss: 9.9687e-04 - mean_squared_error: 9.9687e-04 - val_loss: 8.9157e-04 - val_mean_squared_error: 8.9157e-04
# Epoch 32/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.9542e-04 - mean_squared_error: 9.9542e-04 - val_loss: 8.9859e-04 - val_mean_squared_error: 8.9860e-04
# Epoch 33/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.9525e-04 - mean_squared_error: 9.9525e-04 - val_loss: 9.3041e-04 - val_mean_squared_error: 9.3041e-04
# Epoch 34/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.9578e-04 - mean_squared_error: 9.9578e-04 - val_loss: 9.0977e-04 - val_mean_squared_error: 9.0977e-04
# Epoch 35/100
# 227452/227452 [==============================] - 10s 45us/sample - loss: 9.9617e-04 - mean_squared_error: 9.9617e-04 - val_loss: 9.0861e-04 - val_mean_squared_error: 9.0861e-04
# Epoch 36/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.9521e-04 - mean_squared_error: 9.9521e-04 - val_loss: 9.0198e-04 - val_mean_squared_error: 9.0198e-04
# Epoch 37/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.9475e-04 - mean_squared_error: 9.9475e-04 - val_loss: 8.8243e-04 - val_mean_squared_error: 8.8242e-04
# Epoch 38/100
# 227452/227452 [==============================] - 12s 52us/sample - loss: 9.9463e-04 - mean_squared_error: 9.9463e-04 - val_loss: 8.9061e-04 - val_mean_squared_error: 8.9061e-04
# Epoch 39/100
# 227452/227452 [==============================] - 12s 51us/sample - loss: 9.9242e-04 - mean_squared_error: 9.9242e-04 - val_loss: 8.9152e-04 - val_mean_squared_error: 8.9152e-04
# Epoch 40/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.8777e-04 - mean_squared_error: 9.8777e-04 - val_loss: 9.0039e-04 - val_mean_squared_error: 9.0038e-04
# Epoch 41/100
# 227452/227452 [==============================] - 10s 44us/sample - loss: 9.8507e-04 - mean_squared_error: 9.8508e-04 - val_loss: 8.7490e-04 - val_mean_squared_error: 8.7490e-04
# Epoch 42/100
# 227452/227452 [==============================] - 11s 48us/sample - loss: 9.8154e-04 - mean_squared_error: 9.8154e-04 - val_loss: 9.1254e-04 - val_mean_squared_error: 9.1254e-04
# Epoch 43/100
# 227452/227452 [==============================] - 10s 43us/sample - loss: 9.7666e-04 - mean_squared_error: 9.7666e-04 - val_loss: 9.0044e-04 - val_mean_squared_error: 9.0044e-04
# Epoch 44/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.7373e-04 - mean_squared_error: 9.7373e-04 - val_loss: 8.9459e-04 - val_mean_squared_error: 8.9459e-04
# Epoch 45/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.7110e-04 - mean_squared_error: 9.7111e-04 - val_loss: 9.3769e-04 - val_mean_squared_error: 9.3769e-04
# Epoch 46/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.7006e-04 - mean_squared_error: 9.7006e-04 - val_loss: 8.9006e-04 - val_mean_squared_error: 8.9006e-04
# Epoch 47/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.6849e-04 - mean_squared_error: 9.6849e-04 - val_loss: 8.8471e-04 - val_mean_squared_error: 8.8471e-04
# Epoch 48/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.6779e-04 - mean_squared_error: 9.6779e-04 - val_loss: 8.8473e-04 - val_mean_squared_error: 8.8473e-04
# Epoch 49/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.6738e-04 - mean_squared_error: 9.6738e-04 - val_loss: 8.8452e-04 - val_mean_squared_error: 8.8453e-04
# Epoch 50/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.6662e-04 - mean_squared_error: 9.6662e-04 - val_loss: 8.8228e-04 - val_mean_squared_error: 8.8227e-04
# Epoch 51/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6546e-04 - mean_squared_error: 9.6546e-04 - val_loss: 8.8436e-04 - val_mean_squared_error: 8.8436e-04
# Epoch 52/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.6407e-04 - mean_squared_error: 9.6407e-04 - val_loss: 8.9072e-04 - val_mean_squared_error: 8.9072e-04
# Epoch 53/100
# 227452/227452 [==============================] - 10s 43us/sample - loss: 9.6424e-04 - mean_squared_error: 9.6424e-04 - val_loss: 8.9504e-04 - val_mean_squared_error: 8.9504e-04
# Epoch 54/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.6183e-04 - mean_squared_error: 9.6183e-04 - val_loss: 8.8394e-04 - val_mean_squared_error: 8.8394e-04
# Epoch 55/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.6174e-04 - mean_squared_error: 9.6174e-04 - val_loss: 9.0450e-04 - val_mean_squared_error: 9.0450e-04
# Epoch 56/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.6199e-04 - mean_squared_error: 9.6199e-04 - val_loss: 8.9646e-04 - val_mean_squared_error: 8.9646e-04
# Epoch 57/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6175e-04 - mean_squared_error: 9.6175e-04 - val_loss: 8.6000e-04 - val_mean_squared_error: 8.6000e-04
# Epoch 58/100
# 227452/227452 [==============================] - 9s 40us/sample - loss: 9.6167e-04 - mean_squared_error: 9.6167e-04 - val_loss: 8.6692e-04 - val_mean_squared_error: 8.6692e-04
# Epoch 59/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6032e-04 - mean_squared_error: 9.6032e-04 - val_loss: 8.6227e-04 - val_mean_squared_error: 8.6227e-04
# Epoch 60/100
# 227452/227452 [==============================] - 10s 44us/sample - loss: 9.6000e-04 - mean_squared_error: 9.6000e-04 - val_loss: 8.9386e-04 - val_mean_squared_error: 8.9386e-04
# Epoch 61/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6112e-04 - mean_squared_error: 9.6112e-04 - val_loss: 8.7572e-04 - val_mean_squared_error: 8.7572e-04
# Epoch 62/100
# 227452/227452 [==============================] - 10s 43us/sample - loss: 9.5957e-04 - mean_squared_error: 9.5957e-04 - val_loss: 8.8475e-04 - val_mean_squared_error: 8.8475e-04
# Epoch 63/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6600e-04 - mean_squared_error: 9.6599e-04 - val_loss: 9.1504e-04 - val_mean_squared_error: 9.1504e-04
# Epoch 64/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.6777e-04 - mean_squared_error: 9.6777e-04 - val_loss: 9.0437e-04 - val_mean_squared_error: 9.0437e-04
# Epoch 65/100
# 227452/227452 [==============================] - 12s 54us/sample - loss: 9.6344e-04 - mean_squared_error: 9.6344e-04 - val_loss: 8.8704e-04 - val_mean_squared_error: 8.8703e-04
# Epoch 66/100
# 227452/227452 [==============================] - 12s 53us/sample - loss: 9.6343e-04 - mean_squared_error: 9.6343e-04 - val_loss: 8.6299e-04 - val_mean_squared_error: 8.6299e-04
# Epoch 67/100
# 227452/227452 [==============================] - 12s 54us/sample - loss: 9.6223e-04 - mean_squared_error: 9.6224e-04 - val_loss: 8.7528e-04 - val_mean_squared_error: 8.7528e-04
# Epoch 68/100
# 227452/227452 [==============================] - 12s 52us/sample - loss: 9.5937e-04 - mean_squared_error: 9.5937e-04 - val_loss: 9.0899e-04 - val_mean_squared_error: 9.0899e-04
# Epoch 69/100
# 227452/227452 [==============================] - 12s 54us/sample - loss: 9.5860e-04 - mean_squared_error: 9.5860e-04 - val_loss: 8.6592e-04 - val_mean_squared_error: 8.6592e-04
# Epoch 70/100
# 227452/227452 [==============================] - 11s 49us/sample - loss: 9.5831e-04 - mean_squared_error: 9.5831e-04 - val_loss: 8.5751e-04 - val_mean_squared_error: 8.5751e-04
# Epoch 71/100
# 227452/227452 [==============================] - 10s 44us/sample - loss: 9.5817e-04 - mean_squared_error: 9.5817e-04 - val_loss: 8.7701e-04 - val_mean_squared_error: 8.7701e-04
# Epoch 72/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.5431e-04 - mean_squared_error: 9.5431e-04 - val_loss: 8.7693e-04 - val_mean_squared_error: 8.7693e-04
# Epoch 73/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.5387e-04 - mean_squared_error: 9.5387e-04 - val_loss: 8.6458e-04 - val_mean_squared_error: 8.6458e-04
# Epoch 74/100
# 227452/227452 [==============================] - 9s 42us/sample - loss: 9.5410e-04 - mean_squared_error: 9.5410e-04 - val_loss: 8.5734e-04 - val_mean_squared_error: 8.5734e-04
# Epoch 75/100
# 227452/227452 [==============================] - 9s 41us/sample - loss: 9.5419e-04 - mean_squared_error: 9.5419e-04 - val_loss: 8.7001e-04 - val_mean_squared_error: 8.7001e-04
# Epoch 76/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.5183e-04 - mean_squared_error: 9.5183e-04 - val_loss: 8.5640e-04 - val_mean_squared_error: 8.5640e-04
# Epoch 77/100
# 227452/227452 [==============================] - 10s 42us/sample - loss: 9.5173e-04 - mean_squared_error: 9.5173e-04 - val_loss: 9.1122e-04 - val_mean_squared_error: 9.1122e-04

# %%
train_predicted_x = autoencoder.predict(x=train_data)
train_events_mse = losses.mean_squared_error(train_data, train_predicted_x)
cut_off = np.percentile(train_events_mse, 95)

# %%
import seaborn as sns
plot_samples = 100
# normal event
real_x = test_data[:plot_samples].reshape(plot_samples, n_features)
predicted_x = autoencoder.predict(x=real_x)
normal_events_mse = losses.mean_squared_error(real_x, predicted_x)
normal_events_df = pd.DataFrame({
	'mse': normal_events_mse,
	'n': np.arange(0, plot_samples),
	'anomaly': np.zeros(plot_samples)})



# abnormal event
abnormal_x = scaler.transform(abnormal_events)[:plot_samples].reshape(plot_samples, n_features)
predicted_x = autoencoder.predict(x=abnormal_x)
abnormal_events_mse = losses.mean_squared_error(abnormal_x, predicted_x)
abnormal_events_df = pd.DataFrame({
	'mse': abnormal_events_mse,
	'n': np.arange(0, plot_samples),
	'anomaly': np.ones(plot_samples)})

mse_df = pd.concat([normal_events_df, abnormal_events_df])
plot = sns.lineplot(x=mse_df.n, y=mse_df.mse, hue=mse_df.anomaly)

from matplotlib import lines
line = lines.Line2D(
	xdata=np.arange(0, plot_samples),
	ydata=np.full(plot_samples, cut_off),
	color='#CC2B5E',
	linewidth=1.5,
	linestyle='dashed')

plot.add_artist(line)
plt.title('Threshlold: {threshold}'.format(threshold=cut_off))
plt.show()
